# %%
import pandas as pd
import os
import shutil

# %%
# creating data for positive samples

FILE_PATH = "github-chestxray-dataset/metadata.csv"
IMAGES_PATH = "github-chestxray-dataset/images"

# %%
dataframe = pd.read_csv(FILE_PATH)
dataframe.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
COVID_IMAGES = "Dataset/Covid"

# %%
count = 0

# iterating through dataframe and picking out PA scans with COVID-19 to add to dataset folder

for (i, row) in dataframe.iterrows():
    if "COVID-19" in row["finding"] and row["view"] == "PA":
        filename = row["filename"]
        image_path = os.path.join(IMAGES_PATH, filename)
        target_path = os.path.join(COVID_IMAGES, filename)
        shutil.copy2(image_path, target_path)
        
        count += 1
        print("image", count, "added to covid images folder")
# Out:
# image 1 added to covid images folder
# image 2 added to covid images folder
# image 3 added to covid images folder
# image 4 added to covid images folder
# image 5 added to covid images folder
# image 6 added to covid images folder
# image 7 added to covid images folder
# image 8 added to covid images folder
# image 9 added to covid images folder
# image 10 added to covid images folder
# image 11 added to covid images folder
# image 12 added to covid images folder
# image 13 added to covid images folder
# image 14 added to covid images folder
# image 15 added to covid images folder
# image 16 added to covid images folder
# image 17 added to covid images folder
# image 18 added to covid images folder
# image 19 added to covid images folder
# image 20 added to covid images folder
# image 21 added to covid images folder
# image 22 added to covid images folder
# image 23 added to covid images folder
# image 24 added to covid images folder
# image 25 added to covid images folder
# ...

# %%
import random
KAGGLE_PATH = "kaggle-chest-xray/train/NORMAL"

# %%
NORMAL_IMAGES = "Dataset/Normal"
normal_images_name = os.listdir(KAGGLE_PATH)
random.shuffle(normal_images_name)

for i in range(142):
    image_name = normal_images_name[i]
    image_path = os.path.join(KAGGLE_PATH, image_name)
    target_path = os.path.join(NORMAL_IMAGES, image_name)
    shutil.copy2(image_path, target_path)
    print("image", i, "added to normal images folder")
# Out:
# image 0 added to normal images folder
# image 1 added to normal images folder
# image 2 added to normal images folder
# image 3 added to normal images folder
# image 4 added to normal images folder
# image 5 added to normal images folder
# image 6 added to normal images folder
# image 7 added to normal images folder
# image 8 added to normal images folder
# image 9 added to normal images folder
# image 10 added to normal images folder
# image 11 added to normal images folder
# image 12 added to normal images folder
# image 13 added to normal images folder
# image 14 added to normal images folder
# image 15 added to normal images folder
# image 16 added to normal images folder
# image 17 added to normal images folder
# image 18 added to normal images folder
# image 19 added to normal images folder
# image 20 added to normal images folder
# image 21 added to normal images folder
# image 22 added to normal images folder
# image 23 added to normal images folder
# ...
